# %%
import numpy as np
import pandas as pd
import pandas_profiling

# %%
df = pd.read_csv("oec.csv")
df.head()

df_subset = df.loc[:, [
    "Declination",
    "DiscoveryMethod",
    "HostStarMassSlrMass",
    "HostStarTempK",
    "LastUpdated",
    "PlanetIdentifier",
    "RightAscension"
] ]
df_subset.head()
# Out:
#    Declination DiscoveryMethod  HostStarMassSlrMass  HostStarTempK  \
# 0    +33 18 13              RV                0.889         5627.0
# 1    +33 18 13              RV                0.889         5627.0
# 2  +40 13 14.7         transit                0.460         3584.0
# 3  +40 13 14.7         transit                0.460         3584.0
# 4  +40 13 14.7         transit                0.460         3584.0
#
#   LastUpdated PlanetIdentifier RightAscension
# 0    16/07/11      HD 143761 b       16 01 03
# 1    16/07/11      HD 143761 c       16 01 03
# 2    13/07/15      KOI-1843.03    19 00 03.14
# 3         NaN      KOI-1843.01    19 00 03.14
# 4         NaN      KOI-1843.02    19 00 03.14

# %%
pandas_profiling.ProfileReport(df_subset)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.1.2&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...
