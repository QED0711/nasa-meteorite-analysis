# %%
import numpy as np 
import pandas as pd
import pdb
import requests

from Classifications import *
from keys import *

# %%
df = pd.read_csv("Meteorite_Landings.csv")
df.columns = ['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year',
       'reclat', 'reclong', 'GeoLocation']

# %% [markdown]
# ### Drop mass NaNs & 0.0

# %%
df = df[(df.mass > 0.0) & (df.mass.isna() == False)]
df.shape
# Out:
# (45566, 10)

# %% [markdown]
# ## Classifications

# %%
df = Classifications.classify_subclasses(df)

# %%
df.major_classification.value_counts()
# Out:
# Chondrite        42032
# Achondrite        2178
# Iron              1041
# Stony-Iron         311
# uncategorized        4
# Name: major_classification, dtype: int64

# %%
df.groupby('major_classification').mean()
# Out:
#                                 id           mass     reclat     reclong
# major_classification
# Achondrite            30896.449954    2832.684123 -24.225972   37.769330
# Chondrite             26885.663114    1522.094561 -41.663357   64.302098
# Iron                  17997.889529  494262.887233   8.131944   -6.022987
# Stony-Iron            28007.141479   66261.350830  -2.451259   37.426869
# uncategorized         43302.500000       0.078250 -79.683330  159.750000

# %% [markdown]
# ## Country Coordinates

# %%
lat, long = (0.0, 0.0)
latlng = f"{lat},{long}"

req_str = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={latlng}&key={keys['mapsAPI']}"

# resp = requests.get(req_str).json()
# print(resp)
# for r in resp['results']:
#     if "country" in r['types']:
#         print(r['address_components'][0]['long_name'], "\n")
#         break

# %%
geo_df = df[(df.reclat.isna() == False) 
            & (df.reclong.isna() == False) 
            & (df.GeoLocation != '(0.0, 0.0)') # ocean placeholder
            & (df.GeoLocation != '(-71.5, 35.66667)') # antarctica 1
            & (df.GeoLocation != '(-84.0, 168.0)') # antarctice 2
           ]

geo_df.reset_index(inplace=True)
geo_df[21000:21999][geo_df[21000:21999].reclat > 0]
# Out:
#        index                         name     id nametype           recclass  \
# 21105  31977                   Pedernales  34062    Valid  Iron, IAB complex
# 21106  31978                        Peetz  18783    Valid                 L6
# 21107  31979                     Pei Xian  18784    Valid               Iron
# 21108  31980              Pelona Mountain  18785    Valid                 H5
# 21110  31982                      Penokee  18788    Valid                 H5
# 21111  31983                    Penouille  18789    Valid  Iron, IAB complex
# 21112  31984                          Pep  18791    Valid                 OC
# 21113  31985                     Perryton  18794    Valid                LL6
# 21114  31986                   Perryville  18795    Valid          Iron, IIC
# 21115  31987              Persimmon Creek  18796    Valid      Iron, IAB-sLM
# 21116  31988                Petropavlovka  18802    Valid                 H4
# 21117  31989                Petropavlovsk  18803    Valid    Iron, ungrouped
# 21119  31991  Phillips County (pallasite)  18807    Valid  Pallasite, PMG-an
# 21120  31992                     Phulmari  18810    Valid         Stone-uncl
# 21121  31993                      Picacho  18814    Valid        Iron, IIIAB
# 21122  31994               Pickens County  18815    Valid                 H6
# 21124  31996           Pierceville (iron)  18819    Valid        Iron, IIIAB
# 21125  31997          Pierceville (stone)  18820    Valid                 L6
# 21127  31999                  Pima County  18823    Valid         Iron, IIAB
# 21128  32000                  Pine Bluffs  18824    Valid                  H
# 21130  32002                   Pine River  18826    Valid      Iron, IAB-sLL
# 21133  32005                        Piñon  18828    Valid    Iron, ungrouped
# 21134  32006              Pinto Mountains  18829    Valid                 L6
# 21135  32007                   Pipe Creek  18830    Valid                 H6
# 21138  32010                    Pittsburg  18838    Valid       Iron, IAB-MG
# 21140  32012                       Plains  18839    Valid                 H5
# 21141  32013                   Plains (d)  18840    Valid                 H4
# 21142  32014             Plainview (1917)  18841    Valid                 H5
# 21143  32015             Plainview (1950)  18842    Valid                  H
# 21144  32016                Plainview (c)  18843    Valid                 OC
# ...      ...                          ...    ...      ...                ...
# 21881  35818         Ramlat as Sahmah 407  55502    Valid                 H6
# 21882  35819         Ramlat as Sahmah 408  55503    Valid                 H6
# 21883  35820         Ramlat as Sahmah 409  55504    Valid                 H5
# 21884  35821         Ramlat as Sahmah 410  55505    Valid                 H5
# 21885  35822         Ramlat as Sahmah 411  55506    Valid                 H5
# 21886  35823         Ramlat as Sahmah 412  55507    Valid                 H5
# 21887  35824         Ramlat as Sahmah 413  55508    Valid                 L5
# 21888  35825         Ramlat as Sahmah 414  55509    Valid                 H5
# 21889  35826         Ramlat as Sahmah 415  55510    Valid                 H4
# 21890  35827         Ramlat as Sahmah 416  55511    Valid                 H5
# 21891  35828         Ramlat as Sahmah 417  55512    Valid                 H5
# 21892  35829         Ramlat as Sahmah 418  55513    Valid                 L6
# 21893  35830         Ramlat as Sahmah 419  55514    Valid                 L6
# 21894  35831         Ramlat as Sahmah 420  55658    Valid           Ureilite
# 21895  35832         Ramlat as Sahmah 421  55515    Valid                 L6
# 21896  35833         Ramlat as Sahmah 422  55659    Valid             H3.7-5
# 21897  35834         Ramlat as Sahmah 423  55660    Valid             H3.4-5
# 21898  35835         Ramlat as Sahmah 424  55561    Valid                 L6
# 21899  35836         Ramlat as Sahmah 425  55562    Valid                 H5
# 21900  35837         Ramlat as Sahmah 426  56439    Valid                 H4
# 21901  35838         Ramlat as Sahmah 427  56515    Valid                 H5
# 21902  35839         Ramlat as Sahmah 428  56516    Valid                 L6
# 21903  35840                       Rammya  22383    Valid                 H5
# 21904  35841                Rancho Blanco  22388    Valid      Eucrite-mmict
# 21905  35842     Rancho de la Pila (1882)  22389    Valid        Iron, IIIAB
# 21906  35843               Rancho Gomelia  22391    Valid        Iron, IIIAB
# 21907  35844                    Randsburg  44798    Valid                 L5
# 21908  35845                       Ransom  22393    Valid                 H4
# 21912  35849                       Reager  22401    Valid                 L6
# 21913  35850                      Rebiana  22402    Valid              L/LL5
#
#             mass   fall                    year    reclat    reclong  \
# 21105     691.00  Found  01/01/1980 12:00:00 AM  30.33333  -98.95000
# 21106   11500.00  Found  01/01/1937 12:00:00 AM  40.95000 -103.08333
# 21107  400000.00  Found  01/01/1917 12:00:00 AM  34.70000  117.00000
# 21108     618.00  Found  01/01/1999 12:00:00 AM  33.66667 -108.10000
# 21110    3580.00  Found  01/01/1947 12:00:00 AM  39.35000  -99.91667
# 21111      72.54  Found  01/01/1984 12:00:00 AM  48.85000  -64.43333
# 21896    3879.00  Found  01/01/2010 12:00:00 AM  20.50520   56.48438
# 21897     230.30  Found  01/01/2010 12:00:00 AM  20.49917   56.49815
# 21898      80.00  Found  01/01/2011 12:00:00 AM  20.31322   56.48333
# 21899     263.00  Found  01/01/2011 12:00:00 AM  20.33245   56.47362
# 21900      92.00  Found                     NaN  20.11306   56.39750
# 21901       7.60  Found                     NaN  20.09889   56.40972
# 21902   16247.00  Found                     NaN  20.10361   56.32694
# 21903    2481.00  Found  01/01/1996 12:00:00 AM  31.16667   -3.91667
# 21904     155.00  Found  01/01/1987 12:00:00 AM  24.30000 -102.18333
# 21905   46500.00  Found  01/01/1882 12:00:00 AM  24.11667 -104.30000
# 21906   15650.00  Found  01/01/1975 12:00:00 AM  24.51667 -105.25000
# 21907     112.90  Found  01/01/2005 12:00:00 AM  35.40050 -117.66617
# 21908   15000.00  Found  01/01/1938 12:00:00 AM  38.61667  -99.93333
# 21912     230.00  Found  01/01/1948 12:00:00 AM  39.78333 -100.00000
# 21913     459.00  Found  01/01/1999 12:00:00 AM  24.97833   21.88500
#
#                   GeoLocation major_classification subclass_category
# 21105      (30.33333, -98.95)                 Iron               IAB
# 21106     (40.95, -103.08333)            Chondrite                 L
# 21107           (34.7, 117.0)                 Iron              Iron
# 21108      (33.66667, -108.1)            Chondrite                 H
# 21110      (39.35, -99.91667)            Chondrite                 H
# 21111      (48.85, -64.43333)                 Iron               IAB
# 21112     (33.73, -102.57667)            Chondrite                 C
# 21113  (36.35333, -100.73167)            Chondrite                LL
# 21114      (37.73333, -89.85)                 Iron              Iron
# 21115      (35.05, -84.23333)                 Iron               IAB
# 21116        (48.2, 43.73333)            Chondrite                 H
# 21117       (53.35, 87.18333)                 Iron              Iron
# 21119     (40.45, -102.38333)           Stony-Iron         Pallasite
# 21120        (20.13333, 75.5)           Stony-Iron             Stone
# 21121          (33.2, -105.0)                 Iron             IIIAB
# 21122           (34.5, -84.5)            Chondrite                 H
# 21124  (37.86667, -100.66667)                 Iron             IIIAB
# 21125  (37.86667, -100.66667)            Chondrite                 L
# 21127          (32.2, -111.0)                 Iron              IIAB
# 21128  (41.18333, -104.06667)            Chondrite                 H
# 21130       (44.21667, -89.1)                 Iron               IAB
# 21133      (32.66667, -105.1)                 Iron              Iron
# 21134      (34.0, -115.78333)            Chondrite                 L
# 21135   (29.68333, -98.91667)            Chondrite                 H
# 21138       (40.43333, -80.0)                 Iron               IAB
# 21140  (33.28333, -102.76667)            Chondrite                 H
# 21141      (33.26667, -102.9)            Chondrite                 H
# 21142  (34.11667, -101.78333)            Chondrite                 H
# 21143  (34.11667, -101.78333)            Chondrite                 H
# 21144    (34.125, -101.75667)            Chondrite                 C
# ...                       ...                  ...               ...
# 21881     (20.2206, 56.02072)            Chondrite                 H
# 21882    (20.21792, 56.02118)            Chondrite                 H
# 21883    (20.21758, 56.02125)            Chondrite                 H
# 21884     (20.21668, 56.0217)            Chondrite                 H
# 21885     (20.2024, 56.03262)            Chondrite                 H
# 21886     (20.20273, 56.0323)            Chondrite                 H
# 21887     (20.33115, 56.1962)            Chondrite                 L
# 21888    (20.34138, 56.20582)            Chondrite                 H
# 21889    (20.33513, 56.20237)            Chondrite                 H
# 21890    (20.33532, 56.20263)            Chondrite                 H
# 21891     (20.33407, 56.2037)            Chondrite                 H
# 21892     (20.3936, 56.22002)            Chondrite                 L
# 21893    (20.44685, 56.25488)            Chondrite                 L
# 21894    (20.41705, 56.27492)           Achondrite          Ureilite
# 21895    (20.42458, 56.27817)            Chondrite                 L
# 21896     (20.5052, 56.48438)            Chondrite                 H
# 21897    (20.49917, 56.49815)            Chondrite                 H
# 21898    (20.31322, 56.48333)            Chondrite                 L
# 21899    (20.33245, 56.47362)            Chondrite                 H
# 21900     (20.11306, 56.3975)            Chondrite                 H
# 21901    (20.09889, 56.40972)            Chondrite                 H
# 21902    (20.10361, 56.32694)            Chondrite                 L
# 21903    (31.16667, -3.91667)            Chondrite                 H
# 21904      (24.3, -102.18333)           Achondrite           Eucrite
# 21905      (24.11667, -104.3)                 Iron             IIIAB
# 21906     (24.51667, -105.25)                 Iron             IIIAB
# 21907   (35.4005, -117.66617)            Chondrite                 L
# 21908   (38.61667, -99.93333)            Chondrite                 H
# 21912      (39.78333, -100.0)            Chondrite                 L
# 21913      (24.97833, 21.885)            Chondrite                LL
#
# [378 rows x 13 columns]

# %%
antarctic_df = df[(df.GeoLocation == '(-71.5, 35.66667)') | (df.GeoLocation == '(-84.0, 168.0)')]
antarctic_df.groupby('major_classification').mean()
# Out:
#                                 id         mass     reclat     reclong
# major_classification
# Achondrite            26280.362245   187.689796 -73.285714   54.571431
# Chondrite             24842.045527    76.233004 -76.453484   88.107550
# Iron                  26194.250000  2082.552500 -72.541667   46.694448
# Stony-Iron            23465.714286    16.765714 -78.642857  111.285716

# %%
# import math
# for i in range(math.ceil(geo_df.shape[0] / 1000)):
#     file = f"countries/countries-{i}.csv"
#     with open(file, "w") as f:
#         f.write("id, reclat, reclong, country, country_abrv\n")
    
    #     !type nul > {file}  
# my_str = f"countries/{i}.csv"
# !type nul > {my_str}

# %%
import csv
def get_countries(df, start_idx):
    for i in range(start_idx, df.shape[0]):
        
        file = f"countries/countries-{(i // 1000)}.csv"
        
        row_id, lat, lng = (df.id[i], df.reclat[i], df.reclong[i])
        
        req_str = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={lat},{lng}&key={keys['mapsAPI']}"

        resp = requests.get(req_str).json()

        for r in resp['results']:
            if "country" in r['types']:
                country = r['address_components'][0]['long_name']
                country_short_name = r['address_components'][0]['short_name']
        
        try:    
            with open(file, 'a') as countries:
                country_writer = csv.writer(countries, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

                country_writer.writerow([row_id, lat, lng, country, country_short_name])
        except:
            print(i)
            return
        


# UNCOMMENT TO RUN API CALLS
# get_countries(geo_df[17062:].reset_index())
# get_countries(geo_df.reset_index(), start_idx=0)
get_countries(geo_df[21000:21999][geo_df[21000:21999].reclat > 0], start_idx=0)

# %%
df_test['country'] = countries
df_test
