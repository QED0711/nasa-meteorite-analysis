# %%
import numpy as np 
import pandas as pd
import pdb
import requests

from Classifications import *
from keys import *

# %%
df = pd.read_csv("Meteorite_Landings.csv")
df.columns = ['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year',
       'reclat', 'reclong', 'GeoLocation']

# %% [markdown]
# ### Drop mass NaNs & 0.0

# %%
df = df[(df.mass > 0.0) & (df.mass.isna() == False)]
df.shape
# Out:
# (45566, 10)

# %% [markdown]
# ## Classifications

# %%
df = Classifications.classify_subclasses(df)

# %%
df.major_classification.value_counts()
# Out:
# Chondrite        42032
# Achondrite        2178
# Iron              1041
# Stony-Iron         311
# uncategorized        4
# Name: major_classification, dtype: int64

# %%
df.groupby('major_classification').mean()
# Out:
#                                 id           mass     reclat     reclong
# major_classification
# Achondrite            30896.449954    2832.684123 -24.225972   37.769330
# Chondrite             26885.663114    1522.094561 -41.663357   64.302098
# Iron                  17997.889529  494262.887233   8.131944   -6.022987
# Stony-Iron            28007.141479   66261.350830  -2.451259   37.426869
# uncategorized         43302.500000       0.078250 -79.683330  159.750000

# %% [markdown]
# ## Country Coordinates

# %%
lat, long = (0.0, 0.0)
latlng = f"{lat},{long}"

req_str = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={latlng}&key={keys['mapsAPI']}"

# resp = requests.get(req_str).json()
# print(resp)
# for r in resp['results']:
#     if "country" in r['types']:
#         print(r['address_components'][0]['long_name'], "\n")
#         break

# %%
geo_df = df[(df.reclat.isna() == False) 
            & (df.reclong.isna() == False) 
            & (df.GeoLocation != '(0.0, 0.0)') # ocean placeholder
            & (df.GeoLocation != '(-71.5, 35.66667)') # antarctica 1
            & (df.GeoLocation != '(-84.0, 168.0)') # antarctice 2
           ]

geo_df.reset_index(inplace=True)
geo_slice = geo_df[21000:21999][geo_df[21000:21999].reclat > -75].sort_values('reclat')
geo_slice
# Out:
#        index                         name     id nametype           recclass  \
# 21616  35552                      Rainbow  22374    Valid              CO3.2
# 21126  31998                       Pigick  18821    Valid                 H5
# 21132  32004                     Pinnaroo  18827    Valid    Mesosiderite-A4
# 21118  31990                     Pevensey  18805    Valid                LL5
# 21131  32003                      Pingrup  55547    Valid    H5-melt breccia
# 21910  35847                 Rawlinna 001  22399    Valid  Pallasite, PMG-an
# 21181  32054            Premier Downs 002  55719    Valid              LL5-6
# 21180  32053            Premier Downs 001  18885    Valid                 L5
# 21129  32001                     Pine Dam  18825    Valid                 L5
# 21911  35848                 Rawlinna 002  22400    Valid                 H5
# 21607  35543                   Quinyambie  22365    Valid              LL3.6
# 21172  32044                 Porto Alegre  52091    Valid         Iron, IIIE
# 21166  32038                   Poolowanna  18867    Valid                 H5
# 21184  32057              Prospector Pool  47700    Valid    Iron, ungrouped
# 21109  31981                  Pennyweight  18787    Valid    Iron, ungrouped
# 21188  32061             Puerta de Arauco  18896    Valid               Iron
# 21909  35846                   Rateldraai  22397    Valid        Iron, IIIAB
# 21167  32039                   Poonarunna  18868    Valid                 H5
# 21137  32009                       Pitino  18836    Valid                 H5
# 21190  32063                      Puquios  18903    Valid          Iron, IID
# 21139  32011                Pizzetti Well  55548    Valid                 H5
# 21158  32030               Poeppel Corner  18852    Valid                 L6
# 21610  35546                  Rabbit Flat  22367    Valid                 H6
# 21123  31995             Piedade do Bagre  18817    Valid    Iron, ungrouped
# 21136  32008                     Pirapora  18833    Valid         Iron, IIAB
# 21605  35541                    Quijingue  22362    Valid     Pallasite, PMG
# 21179  32052                    Prambanan  18884    Valid    Iron, ungrouped
# 21803  35740         Ramlat as Sahmah 329  52054    Valid                 H3
# 21735  35672         Ramlat as Sahmah 260  35689    Valid                H~6
# 21724  35661         Ramlat as Sahmah 249  35679    Valid                 R5
# ...      ...                          ...    ...      ...                ...
# 21606  35542                 Quinn Canyon  22364    Valid        Iron, IIIAB
# 21162  32034                Poison Spring  18857    Valid               Iron
# 21154  32026                   Pleasanton  18848    Valid                 H5
# 21185  32058                   Providence  18893    Valid        Iron, IIIAB
# 21908  35845                       Ransom  22393    Valid                 H4
# 21177  32049                 Powellsville  18880    Valid                 H5
# 21110  31982                      Penokee  18788    Valid                 H5
# 21171  32043                       Portis  18875    Valid                  L
# 21178  32051            Prairie Dog Creek  18882    Valid               H3.7
# 21912  35849                       Reager  22401    Valid                 L6
# 21138  32010                    Pittsburg  18838    Valid       Iron, IAB-MG
# 21119  31991  Phillips County (pallasite)  18807    Valid  Pallasite, PMG-an
# 21106  31978                        Peetz  18783    Valid                 L6
# 21128  32000                  Pine Bluffs  18824    Valid                  H
# 21174  32046                       Potter  18878    Valid                 L6
# 21155  32027                     Plymouth  18850    Valid        Iron, IIIAB
# 21196  32069                   Qijiaojing  54610    Valid    Iron, ungrouped
# 21130  32002                   Pine River  18826    Valid      Iron, IAB-sLL
# 21615  35551                       Raguli  22373    Valid               H3.8
# 21611  35547                      Rafrüti  22369    Valid    Iron, ungrouped
# 21116  31988                Petropavlovka  18802    Valid                 H4
# 21147  32019              Plancy-l'Abbaye  18845    Valid                 H4
# 21111  31983                    Penouille  18789    Valid  Iron, IAB complex
# 21157  32029                 Podolkhovsky  51587    Valid                 L6
# 21156  32028                   Podgrodzie  31301    Valid               H4/5
# 21617  35553                       Rakity  22375    Valid                 L3
# 21163  32035                    Polujamki  18861    Valid                 H4
# 21117  31989                Petropavlovsk  18803    Valid    Iron, ungrouped
# 21182  32055                Preobrazhenka  18886    Valid               H3/4
# 21164  32036                    Pomozdino  18863    Valid         Eucrite-cm
#
#              mass   fall                    year    reclat    reclong  \
# 21616     1553.00  Found  01/01/1994 12:00:00 AM -35.90667  141.85500
# 21171       30.00  Found  01/01/1959 12:00:00 AM  39.56667  -98.68333
# 21178     2900.00  Found  01/01/1893 12:00:00 AM  39.63333 -100.50000
# 21912      230.00  Found  01/01/1948 12:00:00 AM  39.78333 -100.00000
# 21138      600.00  Found  01/01/1850 12:00:00 AM  40.43333  -80.00000
# 21119     1360.00  Found  01/01/1935 12:00:00 AM  40.45000 -102.38333
# 21106    11500.00  Found  01/01/1937 12:00:00 AM  40.95000 -103.08333
# 21128     2700.00  Found  01/01/1935 12:00:00 AM  41.18333 -104.06667
# 21174   261000.00  Found  01/01/1941 12:00:00 AM  41.23333 -103.30000
# 21155    14000.00  Found  01/01/1893 12:00:00 AM  41.33333  -86.31667
# 21196   160000.00  Found  01/01/2003 12:00:00 AM  43.75000   92.91667
# 21130     3600.00  Found  01/01/1931 12:00:00 AM  44.21667  -89.10000
# 21615     4239.00  Found  01/01/1972 12:00:00 AM  45.70000   43.70000
# 21611    18200.00  Found  01/01/1886 12:00:00 AM  47.00000    7.83333
# 21116     1773.00  Found  01/01/1916 12:00:00 AM  48.20000   43.73333
# 21147      180.00  Found  01/01/2003 12:00:00 AM  48.66667   -4.05000
# 21111       72.54  Found  01/01/1984 12:00:00 AM  48.85000  -64.43333
# 21157      648.00  Found  01/01/2007 12:00:00 AM  49.66883   42.83250
# 21156        8.90  Found  01/01/2000 12:00:00 AM  50.90333   21.54983
# 21617    11400.00  Found  01/01/1971 12:00:00 AM  51.80000   79.90000
# 21163    18350.00  Found  01/01/1971 12:00:00 AM  52.10000   79.70000
# 21117     7000.00  Found  01/01/1841 12:00:00 AM  53.35000   87.18333
# 21182      418.00  Found  01/01/1949 12:00:00 AM  53.70000   79.50000
# 21164      327.00  Found  01/01/1964 12:00:00 AM  62.20000   54.16667
#
#                   GeoLocation major_classification subclass_category
# 21616    (-35.90667, 141.855)            Chondrite                 C
# 21126    (-35.90667, 141.855)            Chondrite                 H
# 21132  (-35.38333, 140.91667)           Stony-Iron      Mesosiderite
# 21118  (-34.78333, 144.66667)            Chondrite                LL
# 21131  (-33.58316, 118.65662)           Achondrite           breccia
# 21910  (-31.16667, 125.26667)           Stony-Iron         Pallasite
# 21181  (-30.68833, 125.51333)            Chondrite                LL
# 21180  (-30.46667, 125.46667)            Chondrite                 L
# 21129      (-30.41667, 138.0)            Chondrite                 L
# 21911  (-30.36667, 126.08333)            Chondrite                 H
# 21607     (-30.15, 140.98333)            Chondrite                LL
# 21172     (-30.03306, -51.23)                 Iron              Iron
# 21166  (-29.83167, 136.85867)            Chondrite                 H
# 21184     (-29.35, 121.76667)                 Iron              Iron
# 21109  (-29.11667, 122.08333)                 Iron              Iron
# 21188  (-28.88333, -66.66667)                 Iron              Iron
# 21909   (-28.83333, 21.13333)                 Iron             IIIAB
# 21167     (-27.76667, 137.85)            Chondrite                 H
# 21137  (-27.46667, -60.58333)            Chondrite                 H
# 21190     (-27.15, -69.91667)                 Iron              Iron
# 21139  (-26.26167, 120.73333)            Chondrite                 H
# 21158  (-25.78333, 137.93333)            Chondrite                 L
# 21610  (-20.36667, 130.11667)            Chondrite                 H
# 21123  (-18.94167, -44.98333)                 Iron              Iron
# 21136          (-17.3, -45.0)                 Iron              IIAB
# 21605     (-10.75, -39.21667)           Stony-Iron         Pallasite
# 21179   (-7.56667, 110.83333)                 Iron              Iron
# 21803    (20.00125, 56.36586)            Chondrite                 H
# 21735      (20.0018, 56.4922)            Chondrite                 H
# 21724    (20.00237, 56.38473)            Chondrite                 R
# ...                       ...                  ...               ...
# 21606  (38.08333, -115.53333)                 Iron             IIIAB
# 21162     (38.17, -110.36667)                 Iron              Iron
# 21154   (38.18333, -94.71667)            Chondrite                 H
# 21185   (38.56667, -85.23333)                 Iron             IIIAB
# 21908   (38.61667, -99.93333)            Chondrite                 H
# 21177   (38.66667, -82.78333)            Chondrite                 H
# 21110      (39.35, -99.91667)            Chondrite                 H
# 21171   (39.56667, -98.68333)            Chondrite                 L
# 21178      (39.63333, -100.5)            Chondrite                 H
# 21912      (39.78333, -100.0)            Chondrite                 L
# 21138       (40.43333, -80.0)                 Iron               IAB
# 21119     (40.45, -102.38333)           Stony-Iron         Pallasite
# 21106     (40.95, -103.08333)            Chondrite                 L
# 21128  (41.18333, -104.06667)            Chondrite                 H
# 21174      (41.23333, -103.3)            Chondrite                 L
# 21155   (41.33333, -86.31667)                 Iron             IIIAB
# 21196       (43.75, 92.91667)                 Iron              Iron
# 21130       (44.21667, -89.1)                 Iron               IAB
# 21615            (45.7, 43.7)            Chondrite                 H
# 21611         (47.0, 7.83333)                 Iron              Iron
# 21116        (48.2, 43.73333)            Chondrite                 H
# 21147       (48.66667, -4.05)            Chondrite                 H
# 21111      (48.85, -64.43333)                 Iron               IAB
# 21157     (49.66883, 42.8325)            Chondrite                 L
# 21156    (50.90333, 21.54983)            Chondrite                 H
# 21617            (51.8, 79.9)            Chondrite                 L
# 21163            (52.1, 79.7)            Chondrite                 H
# 21117       (53.35, 87.18333)                 Iron              Iron
# 21182            (53.7, 79.5)            Chondrite                 H
# 21164        (62.2, 54.16667)           Achondrite           Eucrite
#
# [405 rows x 13 columns]

# %%
antarctic_df = df[(df.GeoLocation == '(-71.5, 35.66667)') | (df.GeoLocation == '(-84.0, 168.0)')]
antarctic_df.groupby('major_classification').mean()
# Out:
#                                 id         mass     reclat     reclong
# major_classification
# Achondrite            26280.362245   187.689796 -73.285714   54.571431
# Chondrite             24842.045527    76.233004 -76.453484   88.107550
# Iron                  26194.250000  2082.552500 -72.541667   46.694448
# Stony-Iron            23465.714286    16.765714 -78.642857  111.285716

# %%
df_test['country'] = countries
df_test
