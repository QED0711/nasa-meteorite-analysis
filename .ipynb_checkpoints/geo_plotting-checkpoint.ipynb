# %%
# import packages
import geopandas as gpd
import numpy as np
import pandas as pd
from shapely.geometry import Point
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import time
import pandas_profiling
from celluloid import Camera
# %matplotlib inline

# %%
# Read in Data Frame and inspect it
df = pd.read_csv('CSV_MASTERS/population.csv')
df.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation major_classification subclass_category  \
# 0    6.08333     (50.775, 6.08333)            Chondrite                 L
# 1   10.23333  (56.18333, 10.23333)            Chondrite                 H
# 2 -113.00000    (54.21667, -113.0)            Chondrite                 E
# 3  -99.90000     (16.88333, -99.9)           Achondrite       Acapulcoite
# 4  -64.95000   (-33.16667, -64.95)            Chondrite                 L
#
#      country country_abrv  density_km_squared  density_mi_squared
# 0    Germany           DE               233.0                90.0
# 1    Denmark           DK               133.0                52.0
# 2     Canada           CA                 4.0                 1.0
# 3     Mexico           MX                64.0                25.0
# 4  Argentina           AR                16.0                 6.0

# %%
# Make a coordinates column that has a value of a list of longitude and latitude
df['coordinates'] = df[['reclong', 'reclat']].values.tolist()
df.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation major_classification subclass_category  \
# 0    6.08333     (50.775, 6.08333)            Chondrite                 L
# 1   10.23333  (56.18333, 10.23333)            Chondrite                 H
# 2 -113.00000    (54.21667, -113.0)            Chondrite                 E
# 3  -99.90000     (16.88333, -99.9)           Achondrite       Acapulcoite
# 4  -64.95000   (-33.16667, -64.95)            Chondrite                 L
#
#      country country_abrv  density_km_squared  density_mi_squared  \
# 0    Germany           DE               233.0                90.0
# 1    Denmark           DK               133.0                52.0
# 2     Canada           CA                 4.0                 1.0
# 3     Mexico           MX                64.0                25.0
# 4  Argentina           AR                16.0                 6.0
#
#                      coordinates
# 0              [6.08333, 50.775]
# 1  [10.23333, 56.18333000000001]
# 2    [-113.0, 54.21666999999999]
# 3    [-99.9, 16.883329999999994]
# 4            [-64.95, -33.16667]

# %%
# Make the coordinate column a Point object
df['coordinates'] = df['coordinates'].apply(Point)
df.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation major_classification subclass_category  \
# 0    6.08333     (50.775, 6.08333)            Chondrite                 L
# 1   10.23333  (56.18333, 10.23333)            Chondrite                 H
# 2 -113.00000    (54.21667, -113.0)            Chondrite                 E
# 3  -99.90000     (16.88333, -99.9)           Achondrite       Acapulcoite
# 4  -64.95000   (-33.16667, -64.95)            Chondrite                 L
#
#      country country_abrv  density_km_squared  density_mi_squared  \
# 0    Germany           DE               233.0                90.0
# 1    Denmark           DK               133.0                52.0
# 2     Canada           CA                 4.0                 1.0
# 3     Mexico           MX                64.0                25.0
# 4  Argentina           AR                16.0                 6.0
#
#                                     coordinates
# 0                        POINT (6.08333 50.775)
# 1            POINT (10.23333 56.18333000000001)
# 2                POINT (-113 54.21666999999999)
# 3  POINT (-99.90000000000001 16.88332999999999)
# 4                      POINT (-64.95 -33.16667)

# %%
df.sort_values(by=['year'], axis = 0, inplace = True)
df.head(10)
# Out:
#                    name     id nametype      recclass        mass   fall  \
# 674              Nogata  16988    Valid            L6       472.0   Fell
# 268             Elbogen   7823    Valid     Iron, IID    107000.0   Fell
# 817    Rivolta de Bassi  22614    Valid    Stone-uncl       103.3   Fell
# 273           Ensisheim  10039    Valid           LL6    127000.0   Fell
# 6224    Campo del Cielo   5247    Valid  Iron, IAB-MG  50000000.0  Found
# 167       Castrovillari   5295    Valid    Stone-uncl     15000.0   Fell
# 20863            Morito  16745    Valid   Iron, IIIAB  10100000.0  Found
# 393           Jalandhar  12069    Valid          Iron      1967.0   Fell
# 919        Stretchleigh  23732    Valid    Stone-uncl     10400.0   Fell
# 354             Hatford  11855    Valid    Stone-uncl     29000.0   Fell
#
#          year    reclat    reclong             GeoLocation  \
# 674     860.0  33.72500  130.75000        (33.725, 130.75)
# 268    1399.0  50.18333   12.73333    (50.18333, 12.73333)
# 817    1490.0  45.48333    9.51667     (45.48333, 9.51667)
# 273    1491.0  47.86667    7.35000        (47.86667, 7.35)
# 6224   1575.0 -27.46667  -60.58333  (-27.46667, -60.58333)
# 167    1583.0  39.80000   16.20000            (39.8, 16.2)
# 20863  1600.0  27.05000 -105.43333     (27.05, -105.43333)
# 393    1621.0  31.00000   75.00000            (31.0, 75.0)
# 919    1623.0  50.38333   -3.95000       (50.38333, -3.95)
# 354    1628.0  51.65000   -1.51667       (51.65, -1.51667)
#
#       major_classification subclass_category         country country_abrv  \
# 674              Chondrite                 L           Japan           JP
# 268                   Iron              Iron         Czechia           CZ
# 817             Stony-Iron             Stone           Italy           IT
# 273              Chondrite                LL          France           FR
# 6224                  Iron               IAB       Argentina           AR
# 167             Stony-Iron             Stone           Italy           IT
# 20863                 Iron             IIIAB          Mexico           MX
# 393                   Iron              Iron           India           IN
# 919             Stony-Iron             Stone  United Kingdom           GB
# 354             Stony-Iron             Stone  United Kingdom           GB
#
#        density_km_squared  density_mi_squared                  coordinates
# 674                 337.0               130.0        POINT (130.75 33.725)
# 268                   0.0                 0.0    POINT (12.73333 50.18333)
# 817                 201.0                78.0     POINT (9.51667 45.48333)
# 273                 118.0                45.0        POINT (7.35 47.86667)
# 6224                 16.0                 6.0  POINT (-60.58333 -27.46667)
# 167                 201.0                78.0            POINT (16.2 39.8)
# 20863                64.0                25.0     POINT (-105.43333 27.05)
# 393                 411.0               159.0                POINT (75 31)
# 919                 276.0               107.0       POINT (-3.95 50.38333)
# 354                 276.0               107.0       POINT (-1.51667 51.65)

# %%
def to_int(x):
    try:
        return int(x)
    except:
        return 0
    
df.year = df.year.apply(to_int)
df.year.astype("int64", inplace=True)
type(df.year[0])
# Out:
# numpy.int64

# %%
# Export this data frame to the CSV
df.to_csv('CSV_MASTERS/Final.csv', index = False)

# %%
# Making a geopandas dataframe
geo_final = gpd.GeoDataFrame(df, geometry='coordinates', crs={'init': 'epsg:4326'})
print(type(geo_final))
geo_final.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#                         name     id nametype      recclass      mass   fall  \
# 21123   Northwest Africa 058  17068    Valid            L6    1091.0  Found
# 21124   Northwest Africa 059  17069    Valid        H3.9/4   27000.0  Found
# 21145  Northwest Africa 2036  17611    Valid           EL6     390.0  Found
# 21224   Northwest Africa 724  17806    Valid           LL3    1200.0  Found
# 21225   Northwest Africa 725  17807    Valid   Acapulcoite    3824.0  Found
# 21226   Northwest Africa 726  17808    Valid            H4     354.0  Found
# 21274     Nuevo Mercurio (c)  48690    Valid          H5-6      16.8  Found
# 22900   Ramlat as Sahmah 426  56439    Valid            H4      92.0  Found
# 22901   Ramlat as Sahmah 427  56515    Valid            H5       7.6  Found
# 22902   Ramlat as Sahmah 428  56516    Valid            L6   16247.0  Found
# 23121         Río Cuarto 001  44799    Valid       Eucrite      62.7  Found
# 23885    Sayh al Uhaymir 557  56432    Valid            H4       3.0  Found
# 24115       Sleeper Camp 005  23631    Valid            H5     129.0  Found
# 24174            Squaw Creek  23693    Valid    Iron, IIAB   14500.0  Found
# 24589               Um-Hadid  24114    Valid  Mesosiderite   15400.0  Found
# 24661               Valencia  24147    Valid            H5   33500.0  Found
# 24684           Villa Regina  53827    Valid   Iron, IIIAB    5030.0  Found
# 24758        Wietrzno-Bobrka  24259    Valid          Iron     376.0  Found
# 24785              Wiltshire  56143    Valid            H5   92750.0  Found
# 25234               Zaragoza  48916    Valid  Iron, IVA-an  162000.0  Found
#
#        year    reclat    reclong             GeoLocation major_classification  \
# 21123     0  27.16667   -9.50000        (27.16667, -9.5)            Chondrite
# 21124     0  31.83333   -2.93333    (31.83333, -2.93333)            Chondrite
# 21145     0  31.59167   -5.76667    (31.59167, -5.76667)            Chondrite
# 21224     0  30.23333   -5.86667    (30.23333, -5.86667)            Chondrite
# 21225     0  30.60000   -5.05000           (30.6, -5.05)           Achondrite
# 21226     0  31.03333   -4.00000        (31.03333, -4.0)            Chondrite
# 21274     0  24.26000 -102.14083     (24.26, -102.14083)            Chondrite
# 22900     0  20.11306   56.39750     (20.11306, 56.3975)            Chondrite
# 22901     0  20.09889   56.40972    (20.09889, 56.40972)            Chondrite
# 22902     0  20.10361   56.32694    (20.10361, 56.32694)            Chondrite
# 23121     0 -32.87167  -64.22333  (-32.87167, -64.22333)           Achondrite
# 23885     0  20.17417   56.51111    (20.17417, 56.51111)            Chondrite
# 24115     0 -30.17367  126.29233  (-30.17367, 126.29233)            Chondrite
# 24174     0  32.00000  -98.00000           (32.0, -98.0)                 Iron
# 24589     0  21.69500   50.59667      (21.695, 50.59667)           Stony-Iron
# 24661     0  39.00000   -0.03333        (39.0, -0.03333)            Chondrite
# 24684     0 -39.10000  -67.06667      (-39.1, -67.06667)                 Iron
# 24758     0  49.41667   21.70000        (49.41667, 21.7)                 Iron
# 24785     0  51.14967   -1.81000       (51.14967, -1.81)            Chondrite
# 25234     0  41.65000   -0.86667       (41.65, -0.86667)                 Iron
#
#       subclass_category         country country_abrv  density_km_squared  \
# 21123                 L         Morocco           MA                81.0
# 21124                 H         Morocco           MA                81.0
# 21145                 E         Morocco           MA                81.0
# 21224                LL         Morocco           MA                81.0
# 21225       Acapulcoite         Morocco           MA                81.0
# 21226                 H         Morocco           MA                81.0
# 21274                 H          Mexico           MX                64.0
# 22900                 H            Oman           OM                16.0
# 22901                 H            Oman           OM                16.0
# 22902                 L            Oman           OM                16.0
# 23121           Eucrite       Argentina           AR                16.0
# 23885                 H            Oman           OM                16.0
# 24115                 H       Australia           AU                 3.0
# 24174              IIAB   United States           US                35.0
# 24589      Mesosiderite    Saudi Arabia           SA                16.0
# 24661                 H           Spain           ES                92.0
# 24684             IIIAB       Argentina           AR                16.0
# 24758              Iron        Slovakia           SK               111.0
# 24785                 H  United Kingdom           GB               276.0
# 25234              Iron           Spain           ES                92.0
#
#        density_mi_squared                         coordinates
# 21123                31.0               POINT (-9.5 27.16667)
# 21124                31.0           POINT (-2.93333 31.83333)
# 21145                31.0           POINT (-5.76667 31.59167)
# 21224                31.0           POINT (-5.86667 30.23333)
# 21225                31.0                  POINT (-5.05 30.6)
# 21226                31.0                 POINT (-4 31.03333)
# 21274                25.0            POINT (-102.14083 24.26)
# 22900                 6.0            POINT (56.3975 20.11306)
# 22901                 6.0  POINT (56.40971999999999 20.09889)
# 22902                 6.0           POINT (56.32694 20.10361)
# 23121                 6.0         POINT (-64.22333 -32.87167)
# 23885                 6.0           POINT (56.51111 20.17417)
# 24115                 1.0         POINT (126.29233 -30.17367)
# 24174                13.0                      POINT (-98 32)
# 24589                 6.0             POINT (50.59667 21.695)
# 24661                36.0                 POINT (-0.03333 39)
# 24684                 6.0             POINT (-67.06667 -39.1)
# 24758                43.0               POINT (21.7 49.41667)
# 24785               107.0              POINT (-1.81 51.14967)
# 25234                36.0   POINT (-0.8666700000000001 41.65)

# %%
geo_final.sort_values(by=['year'], axis = 0, ascending=False)
#Gives that 2013 is the most recent year
# Out:
#                         name     id nametype       recclass      mass   fall  \
# 187              Chelyabinsk  57165    Valid            LL5  100000.0   Fell
# 19232        Los Vientos 028  57338    Valid            H~5   12110.0  Found
# 9291                  H          Chile           CL                25.0
# 9288                 LL          Chile           CL                25.0
# 9287                 LL          Chile           CL                25.0
# 9281                  L          Chile           CL                25.0
# 9282                  L          Chile           CL                25.0
# 8316                  H           Oman           OM                16.0
# 8315                  L           Oman           OM                16.0
# 9292                  H          Chile           CL                25.0
# ...                 ...            ...          ...                 ...
# 16766                 L           Oman           OM                16.0
# 16767                 L           Oman           OM                16.0
# 16768                 L           Oman           OM                16.0
# 16769                 L           Oman           OM                16.0
# 16771                 L           Oman           OM                16.0
# 16746                 L           Oman           OM                16.0
# 16772                 L           Oman           OM                16.0
# 16773                 L           Oman           OM                16.0
# 16774                 L           Oman           OM                16.0
# 16775                 L           Oman           OM                16.0
# 16776                 L           Oman           OM                16.0
# 16777                 L           Oman           OM                16.0
# 16763                 L           Oman           OM                16.0
# 16762                 L           Oman           OM                16.0
# 16761                 L           Oman           OM                16.0
# 16760                 L           Oman           OM                16.0
# 16759                 H           Oman           OM                16.0
# 16758                 L           Oman           OM                16.0
# 16757                 L           Oman           OM                16.0
# 16756                 H           Oman           OM                16.0
# 16755                 L           Oman           OM                16.0
# 16754                 H           Oman           OM                16.0
# 16753                 L           Oman           OM                16.0
# 16752                 H           Oman           OM                16.0
# 16751                 L           Oman           OM                16.0
# 16750                 L           Oman           OM                16.0
# 16749                 H           Oman           OM                16.0
# 16748                 L           Oman           OM                16.0
# 16747                 L           Oman           OM                16.0
# 25234              Iron          Spain           ES                92.0
#
#        density_mi_squared                           coordinates
# 187                   3.0    POINT (61.11666999999999 54.81667)
# 19232                10.0  POINT (-69.76666999999999 -24.68333)
# 24203                13.0             POINT (-116.18358 36.235)
# 24570                13.0   POINT (-88.77594000000001 34.24216)
# 16950                27.0                  POINT (9.913 32.891)
# 23265                13.0            POINT (-118.1464 34.82793)
# 19595                13.0           POINT (-118.55319 40.89201)
# 16826                13.0           POINT (-117.63728 35.37788)
# 928                  13.0           POINT (-120.90806 38.80389)
# 16820                 6.0    POINT (56.38981999999999 19.77278)
# 4344                 13.0           POINT (-118.54465 40.90183)
# 21241                 7.0            POINT (-13.38527 22.94781)
# 82                   13.0           POINT (-117.18913 40.66813)
# 6266                 10.0  POINT (-69.71666999999999 -25.23333)
# 16949                27.0                  POINT (9.833 32.806)
# 2169                 13.0              POINT (-108.9038 32.306)
# 8317                  6.0    POINT (54.66558000000001 19.13952)
# 9289                 10.0     POINT (-70.53333000000001 -24.85)
# 9279                 10.0     POINT (-70.53333000000001 -24.85)
# 2168                 13.0              POINT (-108.9038 32.306)
# 9278                 10.0     POINT (-70.53333000000001 -24.85)
# 9290                 10.0     POINT (-70.53333000000001 -24.85)
# 9291                 10.0     POINT (-70.53333000000001 -24.85)
# 9288                 10.0     POINT (-70.53333000000001 -24.85)
# 9287                 10.0     POINT (-70.53333000000001 -24.85)
# 9281                 10.0     POINT (-70.53333000000001 -24.85)
# 9282                 10.0     POINT (-70.53333000000001 -24.85)
# 8316                  6.0              POINT (54.88755 19.1823)
# 8315                  6.0     POINT (54.8817 19.18687000000001)
# 9292                 10.0     POINT (-70.53333000000001 -24.85)
# ...                   ...                                   ...
# 16766                 6.0             POINT (56.46556 19.84528)
# 16767                 6.0             POINT (56.46556 19.84528)
# 16768                 6.0             POINT (56.43639 19.84972)
# 16769                 6.0    POINT (56.43833000000001 19.84917)
# 16771                 6.0             POINT (56.46556 19.82306)
# 16746                 6.0    POINT (55.75528000000001 19.74806)
# 16772                 6.0             POINT (56.44722 19.82889)
# 16773                 6.0             POINT (56.44056 19.82361)
# 16774                 6.0     POINT (56.45916999999999 19.8475)
# 16775                 6.0             POINT (56.46056 19.84917)
# 16776                 6.0             POINT (56.46139 19.83528)
# 16777                 6.0             POINT (56.45389 19.85944)
# 16763                 6.0             POINT (56.46972 19.82694)
# 16762                 6.0    POINT (56.49028000000001 19.81333)
# 16761                 6.0             POINT (56.48472 19.78917)
# 16760                 6.0             POINT (56.43583 19.83278)
# 16759                 6.0             POINT (56.39778 19.76806)
# 16758                 6.0              POINT (56.40333 19.7675)
# 16757                 6.0    POINT (56.48278000000001 19.82889)
# 16756                 6.0             POINT (56.30389 19.50583)
# 16755                 6.0             POINT (56.43056 19.18222)
# 16754                 6.0             POINT (56.21417 19.56056)
# 16753                 6.0             POINT (56.22694 19.69611)
# 16752                 6.0             POINT (55.57056 19.56778)
# 16751                 6.0                POINT (55.5825 19.635)
# 16750                 6.0    POINT (55.56333000000001 19.66278)
# 16749                 6.0             POINT (55.69806 19.68111)
# 16748                 6.0               POINT (55.755 19.69889)
# 16747                 6.0    POINT (55.25471999999999 19.69833)
# 25234                36.0     POINT (-0.8666700000000001 41.65)
#
# [33050 rows x 17 columns]

# %% [markdown]
# ### Plotting and Functions for Plotting

# %%
earth = gpd.read_file("custom.geo.json")
earth.plot()

# %%
# Plotting to see one meteor landing location:
# make earth the base figure
# fig, ax = plt.subplots(1, figsize=(30,20))
# base = earth.plot(ax=ax, color='#0B2380',)

# %%
# Function to plot one year
# geo_ISS.plot(ax=base, marker="*", markersize=10, color='#FF4179');
# fig.savefig('ISS path')

def plot_year(df, year_list, column_name_year = 'year', base_axis = base):
    """Given a base figure will plot one years worth of locations
    
        Keyword arguments:
        base_figure -- the axis of a figure and subplot, will be a plot of a shapely object. This is the base that all the years will be plotted on
        df -- pass in the geo data frame with a column that has years and a corrospointing coordinates Shapely Point objects (long, lat) to plot
        year -- enter a year as int
        column_name_year -- enter the column name of the year column
    
    """
    df_year = df[df[column_name_year] == year]
    df_year.plot(ax=base_axis, marker=".", markersize=5,  color='#FF4179')

# %%
fig, ax = plt.subplots(1, figsize=(30,20))
base = earth.plot(ax=ax, color='#0B2380')
plot_year(geo_final, 2000, base_axis = base)

# %%
def plot_years(df, year, column_name_year = 'year', base_axis = base):
    """Given a base figure will plot one years worth of locations
    
        Keyword arguments:
        base_figure -- the axis of a figure and subplot, will be a plot of a shapely object. This is the base that all the years will be plotted on
        df -- pass in the geo data frame with a column that has years and a corrospointing coordinates Shapely Point objects (long, lat) to plot
        year -- enter a year as int
        column_name_year -- enter the column name of the year column
    
    """
    df_year = df[(df[column_name_year] <= year) & (df[column_name_year] > 0)]
    df_year.plot(ax=base_axis, marker=".", markersize=25,  color='#FF4179')

# %%
fig, ax = plt.subplots(1, figsize=(30,20))
base = earth.plot(ax=ax, color='#0B2380')
plot_years(geo_final, 1500, base_axis = base)

# %% [markdown]
# ### Create a geo plotting class

# %%
class GEOplot:
    
    @staticmethod
    # plots one year with a previosly defined figure and base
    def plot_year(df, year, column_name_year = 'year', base_axis = base):
        """Given a base figure will plot one years worth of locations

            Keyword arguments:
            base_figure -- the axis of a figure and subplot, will be a plot of a shapely object. This is the base that all the years will be plotted on
            df -- pass in the geo data frame with a column that has years and a corrospointing coordinates Shapely Point objects (long, lat) to plot
            year -- enter a year as int
            column_name_year -- enter the column name of the year column

        """
        df_year = df[df[column_name_year] == year]
        df_year.plot(ax=base_axis, marker=".", markersize=500,  color='#FF4179')
    
    
    @staticmethod
    # plots everything before  with a previosly defined figure and base
    def plot_years(df, year, column_name_year = 'year', base_axis = base):
        """Given a base figure will plot one years worth of locations

            Keyword arguments:
            base_figure -- the axis of a figure and subplot, will be a plot of a shapely object. This is the base that all the years will be plotted on
            df -- pass in the geo data frame with a column that has years and a corrospointing coordinates Shapely Point objects (long, lat) to plot
            year -- enter a year as int
            column_name_year -- enter the column name of the year column

        """
        df_year = df[(df[column_name_year] <= year) & (df[column_name_year] > 0)]
        df_year.plot(ax=base_axis, marker=".", markersize=500,  color='#FF4179')

# %%
fig, ax = plt.subplots(1, figsize=(30,20))
base = earth.plot(ax=ax, color='#0B2380')
GEOplot.plot_years(geo_final, 1500, base_axis = base)

# %% [markdown]
# ### Animation

# %%
geo_final.year.unique
# Out:
# <bound method Series.unique of 674       860
# 268      1399
# 817      1490
# 273      1491
# 6224     1575
# 167      1583
# 20863    1600
# 393      1621
# 919      1623
# 354      1628
# 604      1632
# 633      1637
# 996      1668
# 705      1671
# 847      1688
# 852      1715
# 24106    1716
# 764      1723
# 24188    1724
# 800      1740
# 691      1741
# 16932    1749
# 371      1751
# 930      1753
# 542      1753
# 19       1766
# 576      1768
# 537      1768
# 861      1773
# 821      1775
#          ...
# 16823       0
# 16882       0
# 20802       0
# 20875       0
# 21116       0
# 21118       0
# 21119       0
# 21120       0
# 21121       0
# 21122       0
# 21123       0
# 21124       0
# 21145       0
# 21224       0
# 21225       0
# 21226       0
# 21274       0
# 22900       0
# 22901       0
# 22902       0
# 23121       0
# 23885       0
# 24115       0
# 24174       0
# 24589       0
# 24661       0
# 24684       0
# 24758       0
# 24785       0
# 25234       0
# Name: year, Length: 33050, dtype: int64>

# %%
year_list = list(geo_final.year.unique())

# %%
# fig = plt.figure()
# camera = Camera(fig)
fig, ax = plt.subplots(1, figsize=(30,20))
    camera = Camera(fig)
    base = earth.plot(ax=ax, color='#31920E')
    base.set_facecolor('#1723EB')

for i in [0,1,2,3, 4, 5]:#range(0, len(year_list)):
    # Initialize a subplot with a figure and base
    
    
    # Plot each year in turn
    GEOplot.plot_year(geo_final, year_list[i], base_axis = base)
    # Set the Legend
    plt.legend([f'Year {year_list[i]}'], fontsize=20)
    
    
    fig.savefig(f'meteor_strikes/year_{year_list[i]}')
    # Snap an image of the produced  image
    camera.snap()
    
animation = camera.animate()
# animation.save('meteors.gif', writer = 'imagemagick')

# %%
earth.head(10)
# Out:
#    scalerank       featurecla  labelrank           sovereignt sov_a3  \
# 0          3  Admin-0 country          5          Netherlands    NL1
# 1          1  Admin-0 country          4          The Bahamas    BHS
# 2          1  Admin-0 country          5             Barbados    BRB
# 3          1  Admin-0 country          6  Antigua and Barbuda    ATG
# 4          3  Admin-0 country          6       United Kingdom    GB1
# 5          1  Admin-0 country          5           Costa Rica    CRI
# 6          1  Admin-0 country          2               Canada    CAN
# 7          1  Admin-0 country          6       United Kingdom    GB1
# 8          1  Admin-0 country          6               Belize    BLZ
# 9          1  Admin-0 country          3                 Cuba    CUB
#
#    adm0_dif  level               type                admin adm0_a3  ...  \
# 0         1      2            Country                Aruba     ABW  ...
# 1         0      2  Sovereign country          The Bahamas     BHS  ...
# 2         0      2  Sovereign country             Barbados     BRB  ...
# 3         0      2  Sovereign country  Antigua and Barbuda     ATG  ...
# 4         1      2         Dependency              Bermuda     BMU  ...
# 5         0      2  Sovereign country           Costa Rica     CRI  ...
# 6         0      2  Sovereign country               Canada     CAN  ...
# 7         1      2         Dependency             Anguilla     AIA  ...
# 8         0      2  Sovereign country               Belize     BLZ  ...
# 9         0      2  Sovereign country                 Cuba     CUB  ...
#
#    region_un         subregion                  region_wb  name_len long_len  \
# 0   Americas         Caribbean  Latin America & Caribbean         5        5
# 1   Americas         Caribbean  Latin America & Caribbean         7        7
# 2   Americas         Caribbean  Latin America & Caribbean         8        8
# 3   Americas         Caribbean  Latin America & Caribbean        17       19
# 4   Americas  Northern America              North America         7        7
# 5   Americas   Central America  Latin America & Caribbean        10       10
# 6   Americas  Northern America              North America         6        6
# 7   Americas         Caribbean  Latin America & Caribbean         8        8
# 8   Americas   Central America  Latin America & Caribbean         6        6
# 9   Americas         Caribbean  Latin America & Caribbean         4        4
#
#   abbrev_len  tiny homepart     filename  \
# 0          5     4      -99  ABW.geojson
# 1          4   -99        1  BHS.geojson
# 2          5     3        1  BRB.geojson
# 3          6     4        1  ATG.geojson
# 4          5     4      -99  BMU.geojson
# 5          4   -99        1  CRI.geojson
# 6          4   -99        1  CAN.geojson
# 7          4   -99      -99  AIA.geojson
# 8          6   -99        1  BLZ.geojson
# 9          4   -99        1  CUB.geojson
#
#                                             geometry
# 0  POLYGON ((-69.89912109375 12.45200195312499, -...
# 1  (POLYGON ((-73.02685546874994 21.1923828125000...
# 2  POLYGON ((-59.49331054687499 13.081982421875, ...
# 3  (POLYGON ((-61.71606445312502 17.0370117187499...
# 4  POLYGON ((-64.73027343749999 32.29345703125, -...
# 5  POLYGON ((-83.64199218749999 10.917236328125, ...
# 6  (POLYGON ((-59.78759765624998 43.9395996093749...
# 7  POLYGON ((-63.00122070312499 18.22177734374999...
# 8  (POLYGON ((-87.85292968749998 17.4228515625, -...
# 9  (POLYGON ((-82.56176757812503 21.5716796875000...
#
# [10 rows x 65 columns]
