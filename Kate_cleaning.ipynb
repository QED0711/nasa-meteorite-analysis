# %%
# import packages
import geopandas as gpd
import numpy as np
import pandas as pd
from shapely.geometry import Point
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import time
import pandas_profiling
# %matplotlib inline

# %%
df = pd.read_csv('Meteorite_Landings.csv')

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
earth = gpd.read_file("custom.geo.json")
earth.plot()

# %%
# drop all the columns but location
geo_location_df =  df.drop(columns = ['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
       'reclat', 'reclong'])
geo_location_df.head()
# Out:
# ------------------------------------------------------
# AttributeError       Traceback (most recent call last)
# <ipython-input-13-470668a78c86> in <module>
#       4 geo_location_df.head()
#       5 # Make the Geo Location as floats
# ----> 6 geo_location_df.GeoLocation[0] = geo_location_df.GeoLocation[0].astype(float)
#       7
#       8 # Make the Geolocation into Point shapely objects
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
geo_location_df.GeoLocation[0][0]
# Out:
# '('

# %%
geo_ISS = geopandas.GeoDataFrame(ISS_df, geometry='coordinates', crs={'init': 'epsg:4326'})

# %%
# Make the Geolocation into Point shapely objects
geo_location_df['GeoLocation'] = geo_location_df['GeoLocation'].apply(Point)
