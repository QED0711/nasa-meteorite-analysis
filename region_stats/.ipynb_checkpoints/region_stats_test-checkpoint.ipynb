# %%
import pandas as pd
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
import seaborn as sns

# %%
earth_strikes = pd.read_csv("CSV_MASTERS/GeoEarth_with_num_strikes")
earth_strikes.tail()
# Out:
#      scalerank       featurecla  labelrank        sovereignt sov_a3  adm0_dif  \
# 120        1.0  Admin-0 country        2.0  Papua New Guinea    PNG       0.0
# 121        NaN              NaN        NaN               NaN    NaN       NaN
# 122        NaN              NaN        NaN               NaN    NaN       NaN
# 123        NaN              NaN        NaN               NaN    NaN       NaN
# 124        NaN              NaN        NaN               NaN    NaN       NaN
#
#      level               type           country adm0_a3     ...      \
# 120    2.0  Sovereign country  Papua New Guinea     PNG     ...
# 121    NaN                NaN        Antarctica     NaN     ...
# 122    NaN                NaN       South Sudan     NaN     ...
# 123    NaN                NaN          Eswatini     NaN     ...
# 124    NaN                NaN           Reunion     NaN     ...
#
#      subregion            region_wb name_len  long_len abbrev_len  tiny  \
# 120  Melanesia  East Asia & Pacific     16.0      16.0        6.0 -99.0
# 121        NaN                  NaN      NaN       NaN        NaN   NaN
# 122        NaN                  NaN      NaN       NaN        NaN   NaN
# 123        NaN                  NaN      NaN       NaN        NaN   NaN
# 124        NaN                  NaN      NaN       NaN        NaN   NaN
#
#      homepart     filename                                           geometry  \
# 120       1.0  PNG.geojson  MULTIPOLYGON (((153.5361328125 -11.47617187499...
# 121       NaN          NaN                                                NaN
# 122       NaN          NaN                                                NaN
# 123       NaN          NaN                                                NaN
# 124       NaN          NaN                                                NaN
#
#     num_strikes
# 120         3.0
# 121     22511.0
# 122         3.0
# 123         1.0
# 124         1.0
#
# [5 rows x 66 columns]

# %%
earth_strikes.loc[121, "subregion"] = "Antarctica"
earth_strikes.loc[121, "region_wb"] = "Antarctica"
earth_strikes.tail()
# Out:
#      scalerank       featurecla  labelrank        sovereignt sov_a3  adm0_dif  \
# 120        1.0  Admin-0 country        2.0  Papua New Guinea    PNG       0.0
# 121        NaN              NaN        NaN               NaN    NaN       NaN
# 122        NaN              NaN        NaN               NaN    NaN       NaN
# 123        NaN              NaN        NaN               NaN    NaN       NaN
# 124        NaN              NaN        NaN               NaN    NaN       NaN
#
#      level               type           country adm0_a3     ...      \
# 120    2.0  Sovereign country  Papua New Guinea     PNG     ...
# 121    NaN                NaN        Antarctica     NaN     ...
# 122    NaN                NaN       South Sudan     NaN     ...
# 123    NaN                NaN          Eswatini     NaN     ...
# 124    NaN                NaN           Reunion     NaN     ...
#
#       subregion            region_wb name_len  long_len abbrev_len  tiny  \
# 120   Melanesia  East Asia & Pacific     16.0      16.0        6.0 -99.0
# 121  Antarctica           Antarctica      NaN       NaN        NaN   NaN
# 122         NaN                  NaN      NaN       NaN        NaN   NaN
# 123         NaN                  NaN      NaN       NaN        NaN   NaN
# 124         NaN                  NaN      NaN       NaN        NaN   NaN
#
#      homepart     filename                                           geometry  \
# 120       1.0  PNG.geojson  MULTIPOLYGON (((153.5361328125 -11.47617187499...
# 121       NaN          NaN                                                NaN
# 122       NaN          NaN                                                NaN
# 123       NaN          NaN                                                NaN
# 124       NaN          NaN                                                NaN
#
#     num_strikes
# 120         3.0
# 121     22511.0
# 122         3.0
# 123         1.0
# 124         1.0
#
# [5 rows x 66 columns]

# %%
region = list(earth_strikes.region_wb.unique())

samples = []

for r in region:
    samples.append(earth_strikes[earth_strikes.region_wb == r].num_strikes)


    
test_results = []
for i in range(len(samples)):
    for j in range(i + 1, len(samples)):
        samp1, samp2 = samples[i], samples[j]
        t_stat, p_value = ttest_ind(samp1, samp2, equal_var=False)
        
        test_results.append((region[i], region[j], t_stat, p_value))
        
region_srikes = pd.DataFrame(test_results, columns=["region_1", "region_2", "t_stat", "p_value"])

region_srikes.dropna()
# Out:
# /home/qdizon/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3194: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /home/qdizon/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                       region_1                    region_2    t_stat   p_value
# 0    Latin America & Caribbean               North America -0.886507  0.534286
# 1    Latin America & Caribbean       Europe & Central Asia  1.238742  0.234426
# 2    Latin America & Caribbean  Middle East & North Africa -0.960486  0.347235
# 3    Latin America & Caribbean                  South Asia  1.056172  0.306036
# 4    Latin America & Caribbean         East Asia & Pacific  0.791141  0.438777
# 5    Latin America & Caribbean          Sub-Saharan Africa  1.220304  0.240944
# 8                North America       Europe & Central Asia  1.055162  0.482911
# 9                North America  Middle East & North Africa  0.594272  0.648478
# 10               North America                  South Asia  1.034743  0.488864
# 11               North America         East Asia & Pacific  1.002038  0.498793
# 12               North America          Sub-Saharan Africa  1.053137  0.483496
# 15       Europe & Central Asia  Middle East & North Africa -1.691377  0.111416
# 16       Europe & Central Asia                  South Asia -0.628847  0.562134
# 17       Europe & Central Asia         East Asia & Pacific -1.126819  0.276092
# 18       Europe & Central Asia          Sub-Saharan Africa -0.169859  0.866096
# 21  Middle East & North Africa                  South Asia  1.603710  0.129055
# 22  Middle East & North Africa         East Asia & Pacific  1.469242  0.161235
# 23  Middle East & North Africa          Sub-Saharan Africa  1.682679  0.113062
# 26                  South Asia         East Asia & Pacific -0.578046  0.570232
# 27                  South Asia          Sub-Saharan Africa  0.542590  0.610881
# 30         East Asia & Pacific          Sub-Saharan Africa  1.061856  0.302558

# %%
# fig = plt.figure(figsize=(20,20))

for i in range(len(samples)):
    for j in range(i + 1, len(samples)):
            samp1, samp2 = samples[i], samples[j]
            plt.figure(figsize=(4,4))
#             fig.add_subplot(3,3, i + 1)
            plt.title(f"{region[i]}-{len(samp1)} V {region[j]}-{len(samp2)}")
            sns.distplot(samp1, kde=True, hist=False)
            sns.distplot(samp2, kde=True, hist=False)
# Out:
# /home/qdizon/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/qdizon/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/qdizon/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py:195: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /home/qdizon/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/qdizon/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
